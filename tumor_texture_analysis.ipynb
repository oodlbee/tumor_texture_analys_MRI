# %%
# !pip install pydicom

# %%
import matplotlib.pyplot as plt
import pydicom
from pydicom.data import get_testdata_files
ds = pydicom.dcmread("suh_before_operation.dcm")
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
cd C:\Users\olsha\projects\Untitled Folder\dicom_images
# Out:
# C:\Users\olsha\projects\Untitled Folder\dicom_images

# %%
ds = pydicom.dcmread("suh_before_operation_T2.dcm")
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7784/2168133369.py in <module>
#       1 ds = pydicom.dcmread("suh_before_operation_T2.dcm")
# ----> 2 plt.figure((20, 20))
#       3 plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
#
# F:\Anconda\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781             num = allnums[inum]
#     782     else:
# --> 783         num = int(num)  # crude validation of num argument
#     784
#     785     manager = _pylab_helpers.Gcf.get_fig_manager(num)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'tuple'
